# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd
df = pd.read_json(r'C:\Users\Desant\Downloads\challenge2-data-science-main\challenge2-data-science-main\TelecomX_Data.json')
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
identif = df.loc[:, ['customerID', 'Churn']]
identif
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %% [markdown]
# #🔧 Transformação

# %%
df_cliente = pd.json_normalize(df['customer'])
df_cliente
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_cliente['tenure'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %%
df_phone = pd.json_normalize(df['phone'])
df_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
df_internet = pd.json_normalize(df['internet'])
df_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
df_internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df_contrato = pd.json_normalize(df['account'])
df_contrato
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_final = pd.concat([identif,df_cliente, df_phone, df_internet, df_contrato], axis=1)
df_final
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_final['Valor Diário'] = df_final['Charges.Monthly'] / 30
df_final.head(1)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
#
#   TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 0         Yes         Yes              No  One year              Yes
#
#   PaymentMethod Charges.Monthly Charges.Total  Valor Diário
# 0  Mailed check            65.6         593.3      2.186667
#
# [1 rows x 22 columns]

# %%
nomes_colunas = {
    'customerID': 'ID Cliente',
    'Churn': 'Churn',
    'gender': 'Gênero',
    'SeniorCitizen': 'Idoso',
    'Partner': 'Parceiro',
    'Dependents': 'Dependentes',
    'tenure': 'Tempo de Contrato (meses)',
    'PhoneService': 'Serviço de Telefone',
    'MultipleLines': 'Linhas Múltiplas',
    'InternetService': 'Serviço de Internet',
    'OnlineSecurity': 'Segurança Online',
    'OnlineBackup': 'Backup Online',
    'DeviceProtection': 'Proteção de Dispositivo',
    'TechSupport': 'Suporte Técnico',
    'StreamingTV': 'Canal de TV',
    'StreamingMovies': 'Canal de Filmes',
    'Contract': 'Tipo de Contrato',
    'PaperlessBilling': 'Fatura Online',
    'PaymentMethod': 'Método de Pagamento',
    'Charges.Monthly': 'Cobrança Mensal',
    'Charges.Total': 'Cobrança Total',
}

# %%
df_final.rename(columns=nomes_colunas, inplace=True)

# %%
df_final.head(10)
# Out:
#    ID Cliente Churn  Gênero  Idoso Parceiro Dependentes  \
# 0  0002-ORFBO    No  Female      0      Yes         Yes
# 1  0003-MKNFE    No    Male      0       No          No
# 2  0004-TLHLJ   Yes    Male      0       No          No
# 3  0011-IGKFF   Yes    Male      1      Yes          No
# 4  0013-EXCHZ   Yes  Female      1      Yes          No
# 5  0013-MHZWF    No  Female      0       No         Yes
# 6  0013-SMEOE    No  Female      1      Yes          No
# 7  0014-BMAQU    No    Male      0      Yes          No
# 8  0015-UOCOJ    No  Female      1       No          No
# 9  0016-QLJIS    No  Female      0      Yes         Yes
#
#    Tempo de Contrato (meses) Serviço de Telefone Linhas Múltiplas  \
# 0                          9                 Yes               No
# 1                          9                 Yes              Yes
# 2                          4                 Yes               No
# 3                         13                 Yes               No
# ...

# %%
df_final['Tempo de Contrato (meses)'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %%
df_final['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID Cliente                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   Gênero                     7267 non-null   object
#  3   Idoso                      7267 non-null   int64
#  4   Parceiro                   7267 non-null   object
#  5   Dependentes                7267 non-null   object
#  6   Tempo de Contrato (meses)  7267 non-null   int64
#  7   Serviço de Telefone        7267 non-null   object
#  8   Linhas Múltiplas           7267 non-null   object
#  9   Serviço de Internet        7267 non-null   object
#  10  Segurança Online           7267 non-null   object
#  11  Backup Online              7267 non-null   object
#  12  Proteção de Dispositivo    7267 non-null   object
# ...

# %%
df_final['Cobrança Total'] = df_final['Cobrança Total'].replace('.','')
df_final['Cobrança Total'] = pd.to_numeric(df_final['Cobrança Total'], errors='coerce')
df_final['Cobrança Total']
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Cobrança Total, Length: 7267, dtype: float64

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID Cliente                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   Gênero                     7267 non-null   object
#  3   Idoso                      7267 non-null   int64
#  4   Parceiro                   7267 non-null   object
#  5   Dependentes                7267 non-null   object
#  6   Tempo de Contrato (meses)  7267 non-null   int64
#  7   Serviço de Telefone        7267 non-null   object
#  8   Linhas Múltiplas           7267 non-null   object
#  9   Serviço de Internet        7267 non-null   object
#  10  Segurança Online           7267 non-null   object
#  11  Backup Online              7267 non-null   object
#  12  Proteção de Dispositivo    7267 non-null   object
# ...

# %% [markdown]
# #📊 Carga e análise

# %%
media_cobranca_mensal = df_final['Cobrança Mensal'].mean()
media_cobranca_total = df_final['Cobrança Total'].mean()
media_gasto_diário = df_final['Valor Diário'].mean()

# %%
import matplotlib.pyplot as plt

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
sns.countplot(x='Churn', data=df_final)
plt.title('Distribuição de Churn')
plt.xlabel('Churn')
plt.ylabel('Contagem')
plt.show()

# %%
df_evasão = df_final[df_final['Churn'] == 'Yes']
df_evasão
# Out:
#       ID Cliente Churn  Gênero  Idoso Parceiro Dependentes  \
# 2     0004-TLHLJ   Yes    Male      0       No          No
# 3     0011-IGKFF   Yes    Male      1      Yes          No
# 4     0013-EXCHZ   Yes  Female      1      Yes          No
# 18    0022-TCJCI   Yes    Male      1       No          No
# 19    0023-HGHWL   Yes    Male      1       No          No
# ...          ...   ...     ...    ...      ...         ...
# 7243  9961-JBNMK   Yes    Male      1       No          No
# 7246  9965-YOKZB   Yes    Male      1       No          No
# 7260  9985-MWVIX   Yes  Female      0       No          No
# 7261  9986-BONCE   Yes  Female      0       No          No
# 7263  9992-RRAMN   Yes    Male      0      Yes          No
#
#       Tempo de Contrato (meses) Serviço de Telefone  Linhas Múltiplas  \
# 2                             4                 Yes                No
# 3                            13                 Yes                No
# ...

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x='Gênero', data=df_evasão, palette='dark')
plt.title('Distribuição de Gênero entre Clientes que Cancelaram')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.yticks(np.arange(0, 1000, 50))
plt.show()
# Out:
# C:\Users\Desant\AppData\Local\Temp\ipykernel_13616\2997683916.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gênero', data=df_evasão, palette='dark')

# %%
df_evasão.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID Cliente                 1869 non-null   object
#  1   Churn                      1869 non-null   object
#  2   Gênero                     1869 non-null   object
#  3   Idoso                      1869 non-null   int64
#  4   Parceiro                   1869 non-null   object
#  5   Dependentes                1869 non-null   object
#  6   Tempo de Contrato (meses)  1869 non-null   int64
#  7   Serviço de Telefone        1869 non-null   object
#  8   Linhas Múltiplas           1869 non-null   object
#  9   Serviço de Internet        1869 non-null   object
#  10  Segurança Online           1869 non-null   object
#  11  Backup Online              1869 non-null   object
#  12  Proteção de Dispositivo    1869 non-null   object
# ...

# %%
sns.set_theme()
sns.countplot(x='Tipo de Contrato', data=df_evasão, palette='dark')
plt.title('Distribuição do Tipo de Contrato entre Clientes que Cancelaram')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Contagem')
plt.yticks(np.arange(0, 1600, 100))
plt.show()
# Out:
# C:\Users\Desant\AppData\Local\Temp\ipykernel_13616\3255085806.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Tipo de Contrato', data=df_evasão, palette='dark')

# %%
sns.set_theme()
sns.countplot(x='Método de Pagamento', data=df_evasão, palette='dark')
plt.title('Cancelamento de contrato por Método de Pagamento')
plt.xlabel('Método de Pagamento')
plt.xticks(rotation=45)
plt.ylabel('Contagem')
plt.yticks(np.arange(0, 1100, 100))
plt.show()
# Out:
# C:\Users\Desant\AppData\Local\Temp\ipykernel_13616\1312284998.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Método de Pagamento', data=df_evasão, palette='dark')

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x='Suporte Técnico', data=df_evasão, palette='dark')
plt.title('Evasão por Suporte Técnico S/N')
plt.xlabel('Suporte Técnico')
plt.ylabel('Contagem')
plt.yticks(np.arange(0, 1600, 200))
plt.show()
# Out:
# C:\Users\Desant\AppData\Local\Temp\ipykernel_13616\1872207693.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Suporte Técnico', data=df_evasão, palette='dark')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Churn', y='Tempo de Contrato (meses)', data=df_final)
plt.title('Boxplot da Cobrança Total por Status de Churn')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Churn', y='Tempo de Contrato (meses)', data=df_final_filter)
plt.title('Boxplot do Tempo de Contrato por Status de Churn')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(data=df_final, x='Tempo de Contrato (meses)', hue='Churn', fill=True, common_norm=False, alpha=0.5)
plt.title('Distribuição de Tempo de Contrato por Status de Churn')
plt.xticks(np.arange(0, 100, 5))
plt.show()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# A análise feita a cima tem como principal objetivo identificar pontos que impactaram fortemente na perda de clientes da empresa Telecom, logo, seguem algumas análises feitas e tambem alguns pontos a serem observados e possíveis melhoras.
#
# Extraimos os dados emitidos no github via .zip e criamos um diretorio local e um online onde fizemos as tratativas e subimos periodicamente conforme alterações. Realizamos a abertura de dados aninhados e separaos as tabelas para podermos entender os tipos de dados que tinhamos em mãos logo após, unificamos os mesmo e verificamos dados nulos ou duplicados e seguimos as análises. Consequentemente chegamos as seguintes conclusões:
#
# - Por mais que esteja equilibrado, o maior número de "Churns" foram de pessoas do sexo feminino
# - O contratos assinados por Mês tiveram o maior número de cancelamentos diferente dos contratos feitos por anos
# - Algo que chamou a atenção foram a quantidade de cancelamentos com a forma de pagamento "Electronic Check" isso mostra uma dificuldade nesse meio de pagamento que tem influenciado fortemente na tomada de decisão do cliente em cancelar.
# - Entretanto vale destacar que a maioria dos "Churns" foram de cliente que não aderiram a assinatura do serviço de Suporte Técnico com menos tempo de espera. É valido rever o processo de suporte técnico normal para tentar elevar o nível da qualidade de serviço, visto que tivemos um menor número de evasão com cliente que aderiram o serviço.
# - Outra proposta interessante seria criar contratos semestrais, visto que temos uma taxa de evasão muito alta com clientes a baixo dos 6 meses.
# -
